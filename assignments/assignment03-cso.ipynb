# %% [markdown]
# # Assignment 3 CSO

# %% [markdown]
# Write a program that retrieves the dataset for the "exchequer account (historical series)" from the CSO, and stores it into a file called "cso.json".
#
# Find the dataset in CSO.ie, try economic and then finance, then finance indicators.

# %% [markdown]
# Importing libraries

# %%
import requests
import json

# %%
url = "https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/FIQ02/JSON-stat/2.0/en"
response = requests.get(url)
data = response.json()

# Storing data to cso.json
with open("cso.json", "w") as file:
    json.dump(data, file)

print("Data saved to cso.json")
# Out:
# Data saved to cso.json

# %% [markdown]
# ### Reference:
# CSO URL: https://data.cso.ie. Finance /
# Financial Indicators / FIQ02 - Exchequer Account (Historical Series) / API Data QUERY / RESTful
# Write JSON to file: https://codingnomads.com/python-301-working-with-json
